# %% [markdown]
# # List comprehension

# %%
#list comprehension
list1=[2,3,4,5]
# list2=[]
# for i in list1:
#     list2.append(i**2)
# print(list2)
list2=[i**2 for i in list1]
print(list2)
# Out:
# [4, 9, 16, 25]

# %%
# for i in range(11):
#     if i%2==0:
#         print(i)

list3=[i for i in range(11) if i%2==0]
print(list3)
# Out:
# [0, 2, 4, 6, 8, 10]

# %%
list4=["suraj","sachin","rahul"]
list5=[i.upper() for i in list4]
print(list5)
# Out:
# ['SURAJ', 'SACHIN', 'RAHUL']

# %% [markdown]
# # dictionary Comphrension

# %%
list1=[1,2,3,4,5]

dict1={i:i**2 for i in list1}
print(dict1)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
count=input("Enter Student Details count:")
result={input("Enter Student Name:"):int(input("Enter Student age:")) for i in range(int(count))}
print(result)
# Out:
# {'suraj': 20, 'aarish': 24}

# %%
p_count=int(input("Enter product details count: "))
result={input("Enter the product name: "):int(input("Enter the product price: ")) for i in range(p_count)}
print(result)
# Out:
# {'chai': 15, 'biscuit': 10, 'coffee': 10}

# %% [markdown]
# # Generator
# - special type of concept where this is implemented with the funciton
# - (where we can iterate the value )
# - value iterated using the generator the entire sequence is not stored in the memory
# - generator does not store entire sequence in the memory
# - multiple value can be returned
# - reserves state (functions doesnt reserve state )
# - **yield** is the keyword for generator
