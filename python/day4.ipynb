# %%
#write a python program to perfom the submission of sum of  first n natural number 
#  , (take the value of n from the user ))
n = int(input("Enter a number: "))
sum = 0
for i in range(1, n + 1):
    sum += i
print("The sum of the first", n, "natural numbers is:", sum)
# Out:
# The sum of the first 3 natural numbers is: 6

# %%
#write a program to print number from 1 to n take the value of n from the user , using for loop 
n = int(input("Enter a number: "))
for i in range(1, n + 1):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
#write a python program to calculate the factorial of numbers using while loop 

n=int(input("Enter your number for factorial "))
fac=1
while n>=1:
    fac=fac*n
    n=n-1
print(fac)

'''
n = int(input("Enter a number: "))
sum = 1
for i in range(1, n + 1):
    sum = sum * i
print("The sum of the first", n, "natural numbers is:", sum)
'''
# Out:
# 6

# %%
#write the python program to print reverse of the number ex. 123 => 321
n=int(input("Enter your number "))
rev=0
digit=0
while n>0:
    digit=n%10
    rev=rev*10+digit
    n=n//10
print(rev)

'''
Same solution small code 
n=input("n")
print(int(n[::-1]))

'''
# Out:
# 123

# %%
#write a python program to print fibonacci series using while loop
#fibonacci series is a series of numbers where each number is the sum of the two preceding ones, usually starting with 0 and 1.
n=int(input("Enter number for fibonacci"))
a=1
b=1
for i in range (1,n+1):
    print(a)
    c=a+b
    a=b
    b=c
# Out:
# 1
# 1
# 2
# 3
# 5
# 8

# %%
#write a program to count the digit in the number 
''' 
same output small code 
n=input("Enter your number ")
print(len(n))
'''

num=int(input("Enter the Number: "))
count=0
while num>0:
    count +=1
    num//=10
print("total digit are: ",count)

# %%
#write a program to check if the number is a armstrong number or not ṣ
#when a numbers digit s are cubed and added together the result is equal to the original number
#then its called armstrong number ex. 153 => 1^3 + 5^3 + 3^3 = 153


n=int(input("Enter your number "))
sum=0
temp=n
while temp>0:
    digit=temp%10
    sum+=digit**3
    temp//=10

if n == sum:
    print(n, "is an Armstrong number")
else:
    print(n, "is not an Armstrong number")
# Out:
# 513 is not an Armstrong number

# %%
#write a python program to check the number is a perfect or not 
#  A number is perfect when the sum of its proper divisors is equal to the number itself. For example, 6 is a perfect number because its divisors are 1, 2, and 3, and their sum is 6.
n = int(input("Enter a number: "))
sum = 0
for i in range(1, n):
    if n % i == 0:
        sum += i

if sum == n:
    print("The number is a perfect number.")
else:
    print("The number is not a perfect number.")
# Out:
# The number is not a perfect number.
