# %%
#write a python program to perfrom addition of two numbers and return there values
def add(a,b):
    return a + b

one=int(input ("add number 1 "))
two=int(input ("add number 2 "))
print(add(one,two))
# 10, 12
# Out:
# 22

# %%
#write a python function to check whether the number is even or not 
def evenodd(a):
    if a%2==0:
        return print(a,"number is even ")
    else :
        return print(a,"number is odd")

one=int(input ("add number  "))
evenodd(one)
# Out:
# 2 number is even

# %%
#write a funciton to find the largest of 3 numbers
def Maxvalue(a,b,c):
    return print("Max is:",max(a,b,c),"[",a,b,c,"]")

one=int(input ("number 1 "))
two=int(input ("number 2 "))
three=int(input ("number 3 "))
Maxvalue(one,two,three)
#2,3,9
# Out:
# Max is: 9 [ 2 3 9 ]

# %%
#write a funciton
